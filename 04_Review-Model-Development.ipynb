# %%
# !pip install Scrapy
# !pip install pytorch
# !pip install resampling

# %%
# !pip install nflgame
# Out:
# Collecting nflgame
#   Using cached https://files.pythonhosted.org/packages/d7/c9/d2fabf632a00fbe1211fa156ae184d8c73e1dbece60aba66f1c63866edd1/nflgame-1.2.20.tar.gz
# Requirement already satisfied: pytz in c:\users\charl\anaconda3\envs\multivariado\lib\site-packages (from nflgame) (2019.1)
# Collecting httplib2 (from nflgame)
#   Using cached https://files.pythonhosted.org/packages/60/55/3902b9f33ad9c15abf447ad91b86ef2d0835a1ae78530f1410c115cf8fe3/httplib2-0.13.1-py3-none-any.whl
# Requirement already satisfied: beautifulsoup4 in c:\users\charl\anaconda3\envs\multivariado\lib\site-packages (from nflgame) (4.7.1)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\charl\anaconda3\envs\multivariado\lib\site-packages (from beautifulsoup4->nflgame) (1.8)
# Building wheels for collected packages: nflgame
#   Building wheel for nflgame (setup.py): started
#   Building wheel for nflgame (setup.py): still running...
#   Building wheel for nflgame (setup.py): still running...
#   Building wheel for nflgame (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\charl\AppData\Local\pip\Cache\wheels\02\f6\1e\de7ca18a0a6605914a43e14650940dcef56546bc4e6b15de61
# Successfully built nflgame
# Installing collected packages: httplib2, nflgame
# Successfully installed httplib2-0.13.1 nflgame-1.2.20

# %% [markdown]
# <a href="https://www.bigdatauniversity.com"><img src = "https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/Images/CCLog.png" width = 300, align = "center"></a>
#
# <h1 align=center><font size=5>Data Analysis with Python</font></h1>

# %% [markdown]
# <h1>Module 4: Model Development</h1>

# %% [markdown]
# <p>In this section, we will develop several models that will predict the price of the car using the variables or features. This is just an estimate but should give us an objective idea of how much the car should cost.</p>

# %% [markdown]
# Some questions we want to ask in this module
# <ul>
#     <li>do I know if the dealer is offering fair value for my trade-in?</li>
#     <li>do I know if I put a fair value on my car?</li>
# </ul>
# <p>Data Analytics, we often use <b>Model Development</b> to help us predict future observations from the data we have.</p>
#
# <p>A Model will help us understand the exact relationship between different variables and how these variables are used to predict the result.</p>

# %% [markdown]
# <h4>Setup</h4>

# %% [markdown]
#  Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# load data and store in dataframe df:

# %% [markdown]
# This dataset was hosted on IBM Cloud object click <a href="https://cocl.us/da0101en_object_storage_skills_network">HERE</a> for free storage.

# %%
pd.options.display.max_columns=50

# %%
# path of data 
path = 'https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/automobileEDA.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length     width  \
# 0  convertible          rwd           front        88.6  0.811148  0.890278
# 1  convertible          rwd           front        88.6  0.811148  0.890278
# 2    hatchback          rwd           front        94.5  0.822681  0.909722
# 3        sedan          fwd           front        99.8  0.848630  0.919444
# 4        sedan          4wd           front        99.4  0.848630  0.922222
#
#    height  curb-weight engine-type num-of-cylinders  engine-size fuel-system  \
# 0    48.8         2548        dohc             four          130        mpfi
# 1    48.8         2548        dohc             four          130        mpfi
# 2    52.4         2823        ohcv              six          152        mpfi
# 3    54.3         2337         ohc             four          109        mpfi
# 4    54.3         2824         ohc             five          136        mpfi
#
#    bore  stroke  compression-ratio  horsepower  peak-rpm  city-mpg  \
# 0  3.47    2.68                9.0       111.0    5000.0        21
# 1  3.47    2.68                9.0       111.0    5000.0        21
# 2  2.68    3.47                9.0       154.0    5000.0        19
# 3  3.19    3.40               10.0       102.0    5500.0        24
# 4  3.19    3.40                8.0       115.0    5500.0        18
#
#    highway-mpg    price  city-L/100km horsepower-binned  diesel  gas
# 0           27  13495.0     11.190476            Medium       0    1
# 1           27  16500.0     11.190476            Medium       0    1
# 2           26  16500.0     12.368421            Medium       0    1
# 3           30  13950.0      9.791667            Medium       0    1
# 4           22  17450.0     13.055556            Medium       0    1

# %% [markdown]
# #  Generalized Linear Model
#
#
# ### https://scikit-learn.org/stable/modules/linear_model.html#

# %% [markdown]
# <h3>1. Linear Regression and Multiple Linear Regression</h3>
#
# http://humanidades.cchs.csic.es/cchs/web_UAE/tutoriales/PDF/Regresion_lineal_multiple_3.pdf

# %% [markdown]
# <h4>Linear Regression</h4>

# %% [markdown]
# <p>One example of a Data  Model that we will be using is</p>
# <b>Simple Linear Regression</b>.
#
# <br>
# <p>Simple Linear Regression is a method to help us understand the relationship between two variables:</p>
# <ul>
#     <li>The predictor/independent variable (X)</li>
#     <li>The response/dependent variable (that we want to predict)(Y)</li>
# </ul>
#
# <p>The result of Linear Regression is a <b>linear function</b> that predicts the response (dependent) variable as a function of the predictor (independent) variable.</p>

# %% [markdown]
# $$
#  Y: Response \ Variable\\
#  X: Predictor \ Variables
# $$

# %% [markdown]
#  <b>Linear function:</b>
# $$
# Yhat = a + b  X
# $$

# %% [markdown]
# <ul>
#     <li>a refers to the <b>intercept</b> of the regression line0, in other words: the value of Y when X is 0</li>
#     <li>b refers to the <b>slope</b> of the regression line, in other words: the value with which Y changes when X increases by 1 unit</li>
# </ul>

# %% [markdown]
# ![RL_01.PNG](attachment:RL_01.PNG)
# ![RL_02.PNG](attachment:RL_02.PNG)

# %% [markdown]
# ![RL_03.PNG](attachment:RL_03.PNG)
# ![RL_04.PNG](attachment:RL_04.PNG)

# %% [markdown]
# ![RL_05.PNG](attachment:RL_05.PNG)

# %% [markdown]
# <h4>Lets load the modules for linear regression</h4>

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# <h4>Create the linear regression object</h4>

# %%
lm = LinearRegression()
lm
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# <h4>How could Highway-mpg help us predict car price?</h4>

# %% [markdown]
# For this example, we want to look at how highway-mpg can help us predict car price.
# Using simple linear regression, we will create a linear function with "highway-mpg" as the predictor variable and the "price" as the response variable.

# %%
X = df[['highway-mpg']]
Y =y= df['price']

# %% [markdown]
# Fit the linear model using highway-mpg.

# %%
lm.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
#  We can output a prediction

# %%
Y_hat=lm.predict(X)
Y_hat[0:5]
# Out:
# array([16236.50464347, 16236.50464347, 17058.23802179, 13771.3045085 ,
#        20345.17153508])

# %% [markdown]
# <h4>What is the value of the intercept (a)?</h4>

# %%
lm.intercept_
# Out:
# 38423.3058581574

# %% [markdown]
# <h4>What is the value of the Slope (b)?</h4>

# %%
lm.coef_
# Out:
# array([-821.73337832])

# %%
from sklearn.metrics import r2_score
# y=y.reshape(-1,1)

lm.score(X,Y)
# Out:
# 0.4965911884339176

# %%
Y_hat=lm.predict(X)

# %%
# plt.scatter(y,Y_hat)
sns.regplot(Y,Y_hat)

# %% [markdown]
# <h3>What is the final estimated linear model we get?</h3>

# %% [markdown]
# As we saw above, we should get a final linear model with the structure:

# %% [markdown]
# $$
# Yhat = a + b  X
# $$

# %% [markdown]
# Plugging in the actual values we get:

# %% [markdown]
# <b>price</b> = 38423.31 - 821.73 x  <b>highway-mpg</b>

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Question #1 a): </h1>
#
# <b>Create a linear regression object?</b>
# </div>

# %%
# Write your code below and press Shift+Enter to execute 
lm1=LinearRegression()
lm1
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- The answer is below:
#
# lm1 = LinearRegression()
# lm1
#
# -->

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1> Question #1 b): </h1>
#
# <b>Train the model using 'engine-size' as the independent variable and 'price' as the dependent variable?</b>
# </div>

# %%
# Write your code below and press Shift+Enter to execute 
X = df[['engine-size']]
Y = df['price']
lm1.fit(X,Y)
lm1
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm1.fit(df[['engine-size']], df[['price']])
lm1
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- The answer is below:
#
# lm1.fit(df[['engine-size']], df[['price']])
# lm1
#
# -->

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Question #1 c):</h1>
#
# <b>Find the slope and intercept of the model?</b>
# </div>

# %% [markdown]
# <h4>Slope</h4>

# %%
# Write your code below and press Shift+Enter to execute 
lm1.coef_
# Out:
# array([[166.86001569]])

# %% [markdown]
# <h4>Intercept</h4>

# %%
# Write your code below and press Shift+Enter to execute 
lm1.intercept_
# Out:
# array([-7963.33890628])

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- The answer is below:
#
# # Slope
# lm1.coef_
# # Intercept
# lm1.intercept_
#
# -->

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Question #1 d): </h1>
#
# <b>What is the equation of the predicted line. You can use x and yhat or 'engine-size' or 'price'?</b>
# </div>

# %% [markdown]
# # You can type you answer here

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- The answer is below:
#
# # using X and Y
# Yhat=38423.31-821.733*X
#
# Price=38423.31-821.733*engine-size
#
# -->

# %% [markdown]
# <h4>Multiple Linear Regression</h4>

# %% [markdown]
# <p>What if we want to predict car price using more than one variable?</p>
#
# <p>If we want to use more variables in our model to predict car price, we can use <b>Multiple Linear Regression</b>.
# Multiple Linear Regression is very similar to Simple Linear Regression, but this method is used to explain the relationship between one continuous response (dependent) variable and <b>two or more</b> predictor (independent) variables.
# Most of the real-world regression models involve multiple predictors. We will illustrate the structure by using four predictor variables, but these results can generalize to any integer:</p>

# %% [markdown]
# $$
# Y: Response \ Variable\\
# X_1 :Predictor\ Variable \ 1\\
# X_2: Predictor\ Variable \ 2\\
# X_3: Predictor\ Variable \ 3\\
# X_4: Predictor\ Variable \ 4\\
# $$

# %% [markdown]
# $$
# a: intercept\\
# b_1 :coefficients \ of\ Variable \ 1\\
# b_2: coefficients \ of\ Variable \ 2\\
# b_3: coefficients \ of\ Variable \ 3\\
# b_4: coefficients \ of\ Variable \ 4\\
# $$

# %% [markdown]
# The equation is given by

# %% [markdown]
# $$
# Yhat = a + b_1 X_1 + b_2 X_2 + b_3 X_3 + b_4 X_4
# $$

# %% [markdown]
# <p>From the previous section  we know that other good predictors of price could be:</p>
# <ul>
#     <li>Horsepower</li>
#     <li>Curb-weight</li>
#     <li>Engine-size</li>
#     <li>Highway-mpg</li>
# </ul>
# Let's develop a model using these variables as the predictor variables.

# %%
Z = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]

# %% [markdown]
# Fit the linear model using the four above-mentioned variables.

# %%
lm.fit(Z, df['price'])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# What is the value of the intercept(a)?

# %%
lm.intercept_
# Out:
# -15806.62462632923

# %% [markdown]
# What are the values of the coefficients (b1, b2, b3, b4)?

# %%
lm.coef_
# Out:
# array([53.49574423,  4.70770099, 81.53026382, 36.05748882])

# %% [markdown]
#  What is the final estimated linear model that we get?

# %% [markdown]
# As we saw above, we should get a final linear function with the structure:
#
# $$
# Yhat = a + b_1 X_1 + b_2 X_2 + b_3 X_3 + b_4 X_4
# $$
#
# What is the linear function we get in this example?

# %% [markdown]
# <b>Price</b> = -15678.742628061467 + 52.65851272 x <b>horsepower</b> + 4.69878948 x <b>curb-weight</b> + 81.95906216 x <b>engine-size</b> + 33.58258185 x <b>highway-mpg</b>

# %%
lm.score(Z,Y)
# Out:
# 0.8093562806577458

# %%
from sklearn.preprocessing import StandardScaler
Z = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]
sc=StandardScaler()
sc.fit(Z,Y)
Z=pd.DataFrame(sc.fit_transform(Z,Y),columns=Z.columns)
lm.fit(Z,Y)
print(lm.score(Z,Y))
# Out:
# 0.8093562806577457

# %%
from sklearn.preprocessing import scale
Z = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]
lm.fit(Z,Y)
lm.score(Z,Y)
# Out:
# 0.8093562806577458

# %%
Z['Z_hat']=lm.predict(Z)
print(r2_score(Y,Z.Z_hat))
sns.regplot(Y,Z.Z_hat)
# Out:
# C:\Users\charl\Anaconda3\envs\Multivariado\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# 0.8093562806577458

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1> Question  #2 a): </h1>
# Create and train a Multiple Linear Regression model "lm2" where the response variable is price, and the predictor variable is 'normalized-losses' and  'highway-mpg'.
# </div>

# %%
# Write your code below and press Shift+Enter to execute 
W=df[['normalized-losses','highway-mpg']]
Y=df[['price']]
# W=sc.fit_transform(W)
# W=scale(W)
lm2=LinearRegression()
lm2.fit(W,Y)
lm2.score(W,Y)
# Out:
# 0.4966263556974878

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- The answer is below:
#
# lm2 = LinearRegression()
# lm2.fit(df[['normalized-losses' , 'highway-mpg']],df['price'])
#
# -->

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Question  #2 b): </h1>
# <b>Find the coefficient of the model?</b>
# </div>

# %%
# Write your code below and press Shift+Enter to execute 
lm2.coef_
# Out:
# array([[   1.49789586, -820.45434016]])

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- The answer is below:
#
# lm2.coef_
#
# -->

# %%
W['W_hat']=lm2.predict(W)
sns.regplot(Y,W.W_hat)
print(r2_score(Y,W.W_hat))
# Out:
# C:\Users\charl\Anaconda3\envs\Multivariado\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# 0.4966263556974878

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))


ax1 = sns.distplot(Y, hist=False, color="r", label="Actual Value")
sns.distplot(W.W_hat, hist=False, color="b", label="Fitted Values", ax=ax1 )


plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price (in dollars)')
plt.ylabel('Proportion of Cars')

plt.show()
plt.close()

# %% [markdown]
# <h3>2)  Model Evaluation using Visualization</h3>

# %% [markdown]
# Now that we've developed some models, how do we evaluate our models and how do we choose the best one? One way to do this is by using visualization.

# %% [markdown]
# import the visualization package: seaborn

# %%
# import the visualization package: seaborn
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# <h3>Regression Plot</h3>

# %% [markdown]
# <p>When it comes to simple linear regression, an excellent way to visualize the fit of our model is by using <b>regression plots</b>.</p>
#
# <p>This plot will show a combination of a scattered data points (a <b>scatter plot</b>), as well as the fitted <b>linear regression</b> line going through the data. This will give us a reasonable estimate of the relationship between the two variables, the strength of the correlation, as well as the direction (positive or negative correlation).</p>

# %% [markdown]
#  Let's visualize Horsepower as potential predictor variable of price:

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.regplot(x="highway-mpg", y="price", data=df)
plt.ylim(0,)
# Out:
# (0, 48279.96553078783)

# %% [markdown]
# <p>We can see from this plot that price is negatively correlated to highway-mpg, since the regression slope is negative.
# One thing to keep in mind when looking at a regression plot is to pay attention to how scattered the data points are around the regression line. This will give you a good indication of the variance of the data, and whether a linear model would be the best fit or not. If the data is too far off from the line, this linear model might not be the best model for this data. Let's compare this plot to the regression plot of "peak-rpm".</p>

# %%
plt.figure(figsize=(width, height))
sns.regplot(x="peak-rpm", y="price", data=df)
plt.ylim(0,)
# Out:
# (0, 47422.919330307624)

# %% [markdown]
# <p>Comparing the regression plot of "peak-rpm" and "highway-mpg" we see that the points for "highway-mpg" are much closer to the generated line and on the average decrease. The points for "peak-rpm" have more spread around the predicted line, and it is much harder to determine if the points are decreasing or increasing as the "highway-mpg" increases.</p>

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Question #3:</h1>
# <b>Given the regression plots above is "peak-rpm" or "highway-mpg" more strongly correlated with "price". Use the method  ".corr()" to verify your answer.</b>
# </div>

# %%
# Write your code below and press Shift+Enter to execute 
df[['peak-rpm','highway-mpg','price']].corr()
# Out:
#              peak-rpm  highway-mpg     price
# peak-rpm     1.000000    -0.058598 -0.101616
# highway-mpg -0.058598     1.000000 -0.704692
# price       -0.101616    -0.704692  1.000000

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- The answer is below:
#
# The variable "peak-rpm" has a stronger correlation with "price", it is approximate -0.704692  compared to   "highway-mpg" which is approximate     -0.101616. You can verify it using the following command:
# df[["peak-rpm","highway-mpg","price"]].corr()
#
# -->

# %% [markdown]
# <h3>Residual Plot</h3>
#
# <p>A good way to visualize the variance of the data is to use a residual plot.</p>
#
# <p>What is a <b>residual</b>?</p>
#
# <p>The difference between the observed value (y) and the predicted value (Yhat) is called the residual (e). When we look at a regression plot, the residual is the distance from the data point to the fitted regression line.</p>
#
# <p>So what is a <b>residual plot</b>?</p>
#
# <p>A residual plot is a graph that shows the residuals on the vertical y-axis and the independent variable on the horizontal x-axis.</p>
#
# <p>What do we pay attention to when looking at a residual plot?</p>
#
# <p>We look at the spread of the residuals:</p>
#
# <p>- If the points in a residual plot are <b>randomly spread out around the x-axis</b>, then a <b>linear model is appropriate</b> for the data. Why is that? Randomly spread out residuals means that the variance is constant, and thus the linear model is a good fit for this data.</p>

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.residplot(df['highway-mpg'], df['price'])
plt.show()

# %%
import scipy.stats as stats
stats.levene(df['highway-mpg'], df['price'])
stats.levene(df.horsepower,df['highway-mpg'],df['curb-weight'],df['engine-size'],df['price'])
# Out:
# LeveneResult(statistic=136.48027627630935, pvalue=4.525870603051381e-93)

# %% [markdown]
# <i>What is this plot telling us?</i>
#
# <p>We can see from this residual plot that the residuals are not randomly spread around the x-axis, which leads us to believe that maybe a non-linear model is more appropriate for this data.</p>

# %% [markdown]
# <h3>Multiple Linear Regression</h3>

# %% [markdown]
# <p>How do we visualize a model for Multiple Linear Regression? This gets a bit more complicated because you can't visualize it with regression or residual plot.</p>
#
# <p>One way to look at the fit of the model is by looking at the <b>distribution plot</b>: We can look at the distribution of the fitted values that result from the model and compare it to the distribution of the actual values.</p>

# %% [markdown]
# First lets make a prediction

# %%
Z = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]

# %%
Y_hat = lm.predict(Z)

# %%
plt.figure(figsize=(width, height))


ax1 = sns.distplot(df['price'], hist=False, color="r", label="Actual Value")
sns.distplot(Y_hat, hist=False, color="b", label="Fitted Values", ax=ax1 )


plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price (in dollars)')
plt.ylabel('Proportion of Cars')

plt.show()
plt.close()

# %% [markdown]
# <p>We can see that the fitted values are reasonably close to the actual values, since the two distributions overlap a bit. However, there is definitely some room for improvement.</p>

# %% [markdown]
# <h2>Part 3: Polynomial Regression and Pipelines</h2>

# %% [markdown]
# <p><b>Polynomial regression</b> is a particular case of the general linear regression model or multiple linear regression models.</p>
# <p>We get non-linear relationships by squaring or setting higher-order terms of the predictor variables.</p>
#
# <p>There are different orders of polynomial regression:</p>
# Although polynomial regression fits a nonlinear model to the data, as a statistical estimation problem it is linear, in the sense that the regression function E(y | x) is linear in the unknown parameters that are estimated from the data. For this reason, polynomial regression is considered to be a special case of multiple linear regression.

# %% [markdown]
# <center><b>Quadratic - 2nd order</b></center>
# $$
# Yhat = a + b_1 X^2 +b_2 X^2
# $$
#
#
# <center><b>Cubic - 3rd order</b></center>
# $$
# Yhat = a + b_1 X^2 +b_2 X^2 +b_3 X^3\\
# $$
#
#
# <center><b>Higher order</b>:</center>
# $$
# Y = a + b_1 X^2 +b_2 X^2 +b_3 X^3 ....\\
# $$

# %% [markdown]
# ![Poli_01.PNG](attachment:Poli_01.PNG)

# %% [markdown]
# https://ljk.imag.fr/membres/Bernard.Ycart/emel/cours/sd/node15.html
# Comparar
# https://towardsdatascience.com/linear-regression-on-boston-housing-dataset-f409b7e4a155
# https://towardsdatascience.com/polynomial-regression-bbe8b9d97491

# %% [markdown]
# <p>We saw earlier that a linear model did not provide the best fit while using highway-mpg as the predictor variable. Let's see if we can try fitting a polynomial model to the data instead.</p>

# %% [markdown]
# <p>We will use the following function to plot the data:</p>

# %%
def PlotPolly(model, independent_variable, dependent_variabble, Name):
    x_new = np.linspace(15, 55, 100) #Return evenly spaced numbers over a specified interval.
    y_new = model(x_new)

    plt.plot(independent_variable, dependent_variabble, '.', x_new, y_new, '-')
#     same as 
#     plt.plot(independent_variable, dependent_variabble, '.')
#     plt.plot(x_new, y_new, '-')
    plt.title('Polynomial Fit with Matplotlib for Price ~ Length')
    ax = plt.gca()
    ax.set_facecolor((0.898, 0.898, 0.898))
    fig = plt.gcf()
    plt.xlabel(Name)
    plt.ylabel('Price of Cars')

    plt.show()
    plt.close()

# %% [markdown]
# lets get the variables

# %%
x = df['highway-mpg']
y = df['price']

# %% [markdown]
# Let's fit the polynomial using the function <b>polyfit</b>, then use the function <b>poly1d</b> to display the polynomial function.

# %%
# Here we use a polynomial of the 3rd order (cubic) 
f = np.polyfit(x, y, 3)
p = np.poly1d(f)
print(p)
# Out:
#         3         2
# -1.557 x + 204.8 x - 8965 x + 1.379e+05

# %% [markdown]
#  Let's plot the function

# %%
PlotPolly(p, x, y, 'highway-mpg')

# %%
np.polyfit(x, y, 3)
# Out:
# array([-1.55663829e+00,  2.04754306e+02, -8.96543312e+03,  1.37923594e+05])

# %%
x = df['highway-mpg']
y = df['price']

X=np.array(x).reshape(-1,1)

from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=3)
X=poly.fit_transform(X)
lm=LinearRegression()
lm.fit(X,y)

poly_hat=lm.predict(X)
poly_hat=poly_hat.reshape(-1,1)

print(lm.score(X,y))

import operator
plt.scatter(x, y,s=10)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,poly_hat), key=sort_axis)
x, poly_hat = zip(*sorted_zip)
plt.plot(x, poly_hat, color='m')
plt.show()
# Out:
# 0.674194666390652

# %% [markdown]
# <p>We can already see from plotting that this polynomial model performs better than the linear model. This is because the generated polynomial function  "hits" more of the data points.</p>

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Question  #4:</h1>
# <b>Create 11 order polynomial model with the variables x and y from above?</b>
# </div>

# %%
# Write your code below and press Shift+Enter to execute 
x = df['highway-mpg']
y = df['price']
f=np.polyfit(x,y,11)
p=np.poly1d(f)
PlotPolly(p,x,y,'highway-mpg')

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- The answer is below:
#
# # calculate polynomial
# # Here we use a polynomial of the 3rd order (cubic)
# f1 = np.polyfit(x, y, 11)
# p1 = np.poly1d(f1)
# print(p)
# PlotPolly(p1,x,y, 'Length')
#
# -->

# %% [markdown]
# <p>The analytical expression for Multivariate Polynomial function gets complicated. For example, the expression for a second-order (degree=2)polynomial with two variables is given by:</p>

# %% [markdown]
# $$
# Yhat = a + b_1 X_1 +b_2 X_2 +b_3 X_1 X_2+b_4 X_1^2+b_5 X_2^2
# $$

# %% [markdown]
# We can perform a polynomial transform on multiple features. First, we import the module:

# %%
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# We create a <b>PolynomialFeatures</b> object of degree 2:

# %%
pr=PolynomialFeatures(degree=2)
pr
# Out:
# PolynomialFeatures(degree=2, include_bias=True, interaction_only=False,
#                    order='C')

# %%
Z = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]
Z_pr=pr.fit_transform(Z)

# %% [markdown]
# The original data is of 201 samples and 4 features

# %%
Z.shape
# Out:
# (201, 4)

# %% [markdown]
# after the transformation, there 201 samples and 15 features

# %%
Z_pr.shape
# Out:
# (201, 15)

# %%
Z_pr[:1]
# Out:
# array([[1.000000e+00, 1.110000e+02, 2.548000e+03, 1.300000e+02,
#         2.700000e+01, 1.232100e+04, 2.828280e+05, 1.443000e+04,
#         2.997000e+03, 6.492304e+06, 3.312400e+05, 6.879600e+04,
#         1.690000e+04, 3.510000e+03, 7.290000e+02]])

# %% [markdown]
# <h2>Pipeline</h2>

# %% [markdown]
# <p>Data Pipelines simplify the steps of processing the data. We use the module <b>Pipeline</b> to create a pipeline. We also use <b>StandardScaler</b> as a step in our pipeline.</p>

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
# >>> from sklearn.pipeline import make_pipeline
# >>> clf = make_pipeline(preprocessing.StandardScaler(), svm.SVC(C=1))
# >>> cross_val_score(clf, iris.data, iris.target, cv=cv)

# %% [markdown]
# We create the pipeline, by creating a list of tuples including the name of the model or estimator and its corresponding constructor.

# %%
Input=[('scale',StandardScaler()), ('polynomial', PolynomialFeatures(degree=2,include_bias=False)), ('model',LinearRegression())]

# %% [markdown]
# we input the list as an argument to the pipeline constructor

# %%
pipe=Pipeline(Input)
pipe
# Out:
# Pipeline(memory=None,
#          steps=[('scale',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('polynomial',
#                  PolynomialFeatures(degree=2, include_bias=False,
#                                     interaction_only=False, order='C')),
#                 ('model',
#                  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#                                   normalize=False))],
#          verbose=False)

# %% [markdown]
# We can normalize the data,  perform a transform and fit the model simultaneously.

# %%
pipe.fit(Z,y)
# Out:
# Pipeline(memory=None,
#          steps=[('scale',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('polynomial',
#                  PolynomialFeatures(degree=2, include_bias=False,
#                                     interaction_only=False, order='C')),
#                 ('model',
#                  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#                                   normalize=False))],
#          verbose=False)

# %% [markdown]
#  Similarly,  we can normalize the data, perform a transform and produce a prediction  simultaneously

# %%
ypipe=pipe.predict(Z)
pipe.score(Z,y)
# Out:
# 0.8463341969864728

# %%
sns.regplot(y,ypipe)

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Question #5:</h1>
# <b>Create a pipeline that Standardizes the data, then perform prediction using a linear regression model using the features Z and targets y</b>
# </div>

# %%
# Write your code below and press Shift+Enter to execute 
from sklearn.pipeline import Pipeline
inp=[('sc',StandardScaler()),('poly',PolynomialFeatures(degree=3)),('lr',LinearRegression())]
pipe=Pipeline(inp)

pipe.fit(Z,y)
pipe_pred=pipe.predict(Z)
pipe.score(Z,y)

sns.regplot(y,pipe_pred)

# %% [markdown]
# </div>
# Double-click <b>here</b> for the solution.
#
# <!-- The answer is below:
#
# Input=[('scale',StandardScaler()),('model',LinearRegression())]
#
# pipe=Pipeline(Input)
#
# pipe.fit(Z,y)
#
# ypipe=pipe.predict(Z)
# ypipe[0:10]
#
# -->

# %% [markdown]
# #  Model evaluation: quantifying the quality of predictions
#
#
# ###  https://scikit-learn.org/stable/modules/model_evaluation.html#

# %% [markdown]
# <h2>Part 4: Measures for In-Sample Evaluation</h2>

# %% [markdown]
# <p>When evaluating our models, not only do we want to visualize the results, but we also want a quantitative measure to determine how accurate the model is.</p>
#
# <p>Two very important measures that are often used in Statistics to determine the accuracy of a model are:</p>
# <ul>
#     <li><b>R^2 / R-squared</b></li>
#     <li><b>Mean Squared Error (MSE)</b></li>
# </ul>
#
# <b>R-squared</b>
#
# <p>R squared, also known as the coefficient of determination, is a measure to indicate how close the data is to the fitted regression line.</p>
#
# <p>The value of the R-squared is the percentage of variation of the response variable (y) that is explained by a linear model.</p>
#
#
#
# <b>Mean Squared Error (MSE)</b>
#
# <p>The Mean Squared Error measures the average of the squares of errors, that is, the difference between actual value (y) and the estimated value (ŷ).</p>

# %% [markdown]
# <h3>Model 1: Simple Linear Regression</h3>

# %% [markdown]
# Let's calculate the R^2

# %%
#highway_mpg_fit
lm.fit(X, Y)
# Find the R^2
print('The R-square is: ', lm.score(X, Y))
# Out:
# The R-square is:  0.674194666390652

# %% [markdown]
# We can say that ~ 49.659% of the variation of the price is explained by this simple linear model "horsepower_fit".

# %% [markdown]
# Let's calculate the MSE

# %% [markdown]
# We can predict the output i.e., "yhat" using the predict method, where X is the input variable:

# %%
Yhat=lm.predict(X)
print('The output of the first four predicted value is: ', Yhat[0:4])
# Out:
# The output of the first four predicted value is:  [[14483.47732606]
#  [14483.47732606]
#  [15876.76908652]
#  [11210.24198667]]

# %% [markdown]
# lets import the function <b>mean_squared_error</b> from the module <b>metrics</b>

# %%
from sklearn.metrics import mean_squared_error

# %% [markdown]
# we compare the predicted results with the actual results

# %%
mse = mean_squared_error(df['price'], Yhat)
print('The mean square error of price and predicted value is: ', mse)
# Out:
# The mean square error of price and predicted value is:  20474146.426361207

# %% [markdown]
# <h3>Model 2: Multiple Linear Regression</h3>

# %% [markdown]
# Let's calculate the R^2

# %%
# fit the model 
lm.fit(Z, df['price'])
# Find the R^2
print('The R-square is: ', lm.score(Z, df['price']))
# Out:
# The R-square is:  0.8093562806577458

# %% [markdown]
# We can say that ~ 80.896 % of the variation of price is explained by this multiple linear regression "multi_fit".

# %% [markdown]
# Let's calculate the MSE

# %% [markdown]
#  we produce a prediction

# %%
Y_predict_multifit = lm.predict(Z)

# %% [markdown]
#  we compare the predicted results with the actual results

# %%
print('The mean square error of price and predicted value using multifit is: ', \
      mean_squared_error(df['price'], Y_predict_multifit))
# Out:
# The mean square error of price and predicted value using multifit is:  11980366.870726489

# %% [markdown]
# <h3>Model 3: Polynomial Fit</h3>

# %% [markdown]
# Let's calculate the R^2

# %% [markdown]
# let’s import the function <b>r2_score</b> from the module <b>metrics</b> as we are using a different function

# %%
from sklearn.metrics import r2_score

# %% [markdown]
# We apply the function to get the value of r^2

# %%
r_squared = r2_score(y, p(x))
print('The R-square value is: ', r_squared)
# Out:
# The R-square value is:  0.7023769093347487

# %% [markdown]
# We can say that ~ 67.419 % of the variation of price is explained by this polynomial fit

# %% [markdown]
# <h3>MSE</h3>

# %% [markdown]
# We can also calculate the MSE:

# %%
mean_squared_error(df['price'], p(x))
# Out:
# 18703127.633425873

# %% [markdown]
# <h2>Part 5: Prediction and Decision Making</h2>
# <h3>Prediction</h3>
#
# <p>In the previous section, we trained the model using the method <b>fit</b>. Now we will use the method <b>predict</b> to produce a prediction. Lets import <b>pyplot</b> for plotting; we will also be using some functions from numpy.</p>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %% [markdown]
# Create a new input

# %%
new_input=np.arange(1, 100, 1).reshape(-1, 1)
#Secuencia de numeros del 1-100 de uno en uno 
X = df[['highway-mpg']]
Y = df['price']

# %% [markdown]
#  Fit the model

# %%
lm.fit(X,Y)
lm.score(X,Y)
# Out:
# 0.4965911884339176

# %%
from sklearn.metrics import mean_squared_error as MSE
MSE(X,Y)
# Out:
# 236536299.00995025

# %% [markdown]
# Produce a prediction

# %%
yhat=lm.predict(new_input)

# %% [markdown]
# we can plot the data

# %%
plt.plot(new_input, yhat)
plt.show()

# %% [markdown]
# <h3>Decision Making: Determining a Good Model Fit</h3>

# %% [markdown]
# <p>Now that we have visualized the different models, and generated the R-squared and MSE values for the fits, how do we determine a good model fit?
# <ul>
#     <li><i>What is a good R-squared value?</i></li>
# </ul>
# </p>
#
# <p>When comparing models, <b>the model with the higher R-squared value is a better fit</b> for the data.
# <ul>
#     <li><i>What is a good MSE?</i></li>
# </ul>
# </p>
#
# <p>When comparing models, <b>the model with the smallest MSE value is a better fit</b> for the data.</p>
#
#
# <h4>Let's take a look at the values for the different models.</h4>
# <p>Simple Linear Regression: Using Highway-mpg as a Predictor Variable of Price.
# <ul>
#     <li>R-squared: 0.49659118843391759</li>
#     <li>MSE: 3.16 x10^7</li>
# </ul>
# </p>
#
# <p>Multiple Linear Regression: Using Horsepower, Curb-weight, Engine-size, and Highway-mpg as Predictor Variables of Price.
# <ul>
#     <li>R-squared: 0.80896354913783497</li>
#     <li>MSE: 1.2 x10^7</li>
# </ul>
# </p>
#
# <p>Polynomial Fit: Using Highway-mpg as a Predictor Variable of Price.
# <ul>
#     <li>R-squared: 0.6741946663906514</li>
#     <li>MSE: 2.05 x 10^7</li>
# </ul>
# </p>

# %% [markdown]
# <h3>Simple Linear Regression model (SLR) vs Multiple Linear Regression model (MLR)</h3>

# %% [markdown]
# <p>Usually, the more variables you have, the better your model is at predicting, but this is not always true. Sometimes you may not have enough data, you may run into numerical problems, or many of the variables may not be useful and or even act as noise. As a result, you should always check the MSE and R^2.</p>
#
# <p>So to be able to compare the results of the MLR vs SLR models, we look at a combination of both the R-squared and MSE to make the best conclusion about the fit of the model.
# <ul>
#     <li><b>MSE</b>The MSE of SLR is  3.16x10^7  while MLR has an MSE of 1.2 x10^7.  The MSE of MLR is much smaller.</li>
#     <li><b>R-squared</b>: In this case, we can also see that there is a big difference between the R-squared of the SLR and the R-squared of the MLR. The R-squared for the SLR (~0.497) is very small compared to the R-squared for the MLR (~0.809).</li>
# </ul>
# </p>
#
# This R-squared in combination with the MSE show that MLR seems like the better model fit in this case, compared to SLR.

# %% [markdown]
# <h3>Simple Linear Model (SLR) vs Polynomial Fit</h3>

# %% [markdown]
# <ul>
#     <li><b>MSE</b>: We can see that Polynomial Fit brought down the MSE, since this MSE is smaller than the one from the SLR.</li>
#     <li><b>R-squared</b>: The R-squared for the Polyfit is larger than the R-squared for the SLR, so the Polynomial Fit also brought up the R-squared quite a bit.</li>
# </ul>
# <p>Since the Polynomial Fit resulted in a lower MSE and a higher R-squared, we can conclude that this was a better fit model than the simple linear regression for predicting Price with Highway-mpg as a predictor variable.</p>

# %% [markdown]
# <h3>Multiple Linear Regression (MLR) vs Polynomial Fit</h3>

# %% [markdown]
# <ul>
#     <li><b>MSE</b>: The MSE for the MLR is smaller than the MSE for the Polynomial Fit.</li>
#     <li><b>R-squared</b>: The R-squared for the MLR is also much larger than for the Polynomial Fit.</li>
# </ul>

# %% [markdown]
# <h2>Conclusion:</h2>

# %% [markdown]
# <p>Comparing these three models, we conclude that <b>the MLR model is the best model</b> to be able to predict price from our dataset. This result makes sense, since we have 27 variables in total, and we know that more than one of those variables are potential predictors of the final car price.</p>

# %% [markdown]
# <h1>Thank you for completing this notebook</h1>

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
#     <p><a href="https://cocl.us/skills_network_DA0101EN_bottom"><img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/Images/BottomAd.png" width="750" align="center"></a></p>
# </div>

# %% [markdown]
# <h3>About the Authors:</h3>
#
# This notebook was written by <a href="https://www.linkedin.com/in/mahdi-noorian-58219234/" target="_blank">Mahdi Noorian PhD</a>, <a href="https://www.linkedin.com/in/joseph-s-50398b136/" target="_blank">Joseph Santarcangelo</a>, Bahare Talayian, Eric Xiao, Steven Dong, Parizad, Hima Vsudevan and <a href="https://www.linkedin.com/in/fiorellawever/" target="_blank">Fiorella Wenver</a> and <a href=" https://www.linkedin.com/in/yi-leng-yao-84451275/ " target="_blank" >Yi Yao</a>.
#
# <p><a href="https://www.linkedin.com/in/joseph-s-50398b136/" target="_blank">Joseph Santarcangelo</a> is a Data Scientist at IBM, and holds a PhD in Electrical Engineering. His research focused on using Machine Learning, Signal Processing, and Computer Vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.</p>

# %% [markdown]
# <hr>
# <p>Copyright &copy; 2018 IBM Developer Skills Network. This notebook and its source code are released under the terms of the <a href="https://cognitiveclass.ai/mit-license/">MIT License</a>.</p>

# %%
import requests
import urllib.request
import time
from bs4 import BeautifulSoup

# %%
url = "https://www.nfl.com/gamecenter/2018090910/2018/REG1/cowboys@panthers"
data=requests.get(url)
html = BeautifulSoup(data.text, 'html.parser')

# %%
html.select('script')
# Out:
# [<script>
#              if ("performance" in window) {
#                  if ("mark" in performance) {
#                      performance.mark("render_ttfr_start");
#                  } else if ("now" in performance) {
#                      window.render_ttfr_start = performance.now();
#                  }
#              }
#          </script>,
#  <script async="" src="https://cdns.gigya.com/js/gigya.js?apiKey=3_B_TsovS9oARceRYcoV0N1WWi6X4kE4DOv33B-uvDe0BxGXmRBKTDawfdH7DbY_rx" type="text/javascript"></script>,
#  <script async="" src="//apv-launcher.minute.ly/api/v3/launcher/MIN-70000.js" type="text/javascript">
#  </script>,
#  <script data-react-helmet="true">window["adrum-app-key"] = "AD-AAB-AAB-XGE";
#      window["adrum-start-time"] = new Date().getTime();</script>,
#  <script async="true" data-react-helmet="true" defer="true" src="//www.googletagservices.com/tag/js/gpt.js"></script>,
#  <script async="true" data-react-helmet="true" defer="true" src="//p.nfltags.com/omniture/dtm/gridiron-v2/d51a64fedd178a47928591706cfcb7e883ce6cca/satelliteLib-0dc380d0fd2cf590584dd7e99228647904eb98ba.js"></script>,
#  <script data-react-helmet="true" type="application/ld+json">{
#          "@context": "https://schema.org",
#          "@type": "SportsOrganization",
#          "name": "NFL",
#          "alternateName": "National Football League",
#          "url": "https://www.nfl.com",
#          "description": "Follow the Dallas Cowboys vs. Carolina Panthers on Sunday, September 9, 2018. Watch the live drive chart and real-time highlights, get stats and game insights, and discover how to watch the game and buy tickets.",
#          "logo": "https://static.nfl.com/static/content/public/static/img/navigation/shields/header-shield.png",
#          "sameAs": [
#              "https://www.youtube.com/user/NFL",
#              "https://twitter.com/nfl",
#              "https://www.facebook.com/NFL",
#              "https://www.instagram.com/nfl/",
#              "https://www.linkedin.com/company/national-football-league",
#              "https://www.pinterest.com/NFL/",
#              "https://plus.google.com/+NFL"
#          ]
#          }</script>,
#  <script>
#              // Register service worker, disable service workers in mobile safari
#              (function() {
#                  function isMobileSafari() {
#                      var ua = window.navigator.userAgent;
#                      var iOS = !!ua.match(/iPad/i) || !!ua.match(/iPhone/i);
#                      var webkit = !!ua.match(/WebKit/i);
#                      return iOS && webkit && !ua.match(/CriOS/i);
#                  }
#                  var isSafari = window.safari !== undefined;
#
#                  if (isSafari || isMobileSafari()){
#                      console.log("Service worker: Event - Skipping Registration");
#                      if("serviceWorker" in navigator){
#                          navigator.serviceWorker.getRegistrations().then(function(registrations) {
#                            if (!registrations.length) {
#                              console.log("Service worker: Event - No Service Worker Registrations Found.");
#                              return;
#                            }
#                            for (let registration of registrations) {
#                              registration.unregister().then(function (boolean) {
#                                  console.log(boolean ? "Service worker: Event - Successfully unregistered" : "Service worker: Event - Failed to unregister");
#                              });
#                            }
#                          })
#                      }
#                  } else if("serviceWorker" in navigator && location.protocol === "https:") {
#                      console.log("Service worker: Event - Registration");
#                      navigator
#                          .serviceWorker
#                          .register("/serviceWorker.js?ead5f554f477d3332b11")
#                          .catch(function (e) {
#                              console.error("Error during service worker registration:", e);
#                          });
#                  } else {
#                     console.log("Service Worker: Event - Unknown Status");
#                  }
#              })()
#          </script>,
#  <script>
#              __INITIAL_DATA__ = {"uiState":{"browserPanel":{"backgroundColor":"#eeeeee","backgroundImage":null,"backgroundPosition":null,"blingDomestic":{"id":"2b18da7c-5162-40fb-8550-c0d2b7a96f06","immediate":true,"refreshInterval":null,"site":{"value":"gamecenter"},"sizeMapping":[{"slot":{"value":[1,1]},"slotSizes":[{"value":[1,1]}],"viewport":{"value":[0,0]}}],"slot":{"value":"background"}},"blingInternational":null,"isAdServed":true},"hasFetchedScoreStripGames":false,"leagueInitiative":"nfl100","mobileHotButton":{"metrics":null,"target":null,"text":"NFL 100","url":"https://www.nfl.com/100/"},"mobileHotButton2":{"metrics":null,"target":null,"text":"Fantasy","url":"https://smart.link/5cbf8a0a565e0?site_id=NFL&creative_id=Hot_button&cp_0=home"},"pageFooterId":"26261d4e-27e1-461e-bf42-55a6b5a07254","pageFooterState":"visible","pageHeaderState":"visible","pageNavigationData":{"globalNavigation":{"primaryLinks":[{"metrics":{"eventName":"clickAction","linkModule":"navigation","linkName":"News","linkType":"global nav","linkUrl":"https://www.nfl.com/news"},"target":null,"text":"News","url":"https://www.nfl.com/news"},{"metrics":{"eventName":"clickAction","linkModule":"navigation","linkName":"Scores","linkType":"global nav","linkUrl":"https://www.nfl.com/scores"},"target":null,"text":"Scores","url":"/scores"},{"metrics":{"eventName":"clickAction","linkModule":"navigation","linkName":"Schedule","linkType":"global nav","linkUrl":"https://www.nfl.com/schedules"},"target":null,"text":"Schedule","url":"https://www.nfl.com/schedules"},{"metrics":{"eventName":"clickAction","linkModule":"navigation","linkName":"Standings","linkType":"global nav","linkUrl":"https://www.nfl.com/standings/division/2018/REG"},"target":null,"text":"Standings","url":"/standings/division/2018/REG"},{"metrics":{"eventName":"clickAction","linkModule":"navigation","linkName":"Training Camp","linkType":"global nav","linkUrl":"http://www.nfl.com/trainingcamp"},"target":null,"text":"Training Camp","url":"http://www.nfl.com/trainingcamp"},{"metrics":{"eventName":"clickAction","linkModule":"navigation","linkName":"Watch Games","linkType":"global nav","linkUrl":"https://www.nfl.com/gamepass?icampaign=nfl-nav-gamepass"},"target":null,"text":"Watch Games","url":"https://www.nfl.com/gamepass?icampaign=nfl-nav-gamepass"},{"metrics":{"eventName":"clickAction","linkModule":"navigation","linkName":"NFL 100","linkType":"global nav","linkUrl":"https://www.nfl.com/100"},"target":"_blank","text":"NFL 100","url":"/100"}],"secondaryLinks":[{"metrics":{"eventName":"clickAction","linkModule":"navigation","linkName":"Super Bowl","linkType":"global nav","linkUrl":"https://www.nfl.com/super-bowl"},"target":null,"text":"Super Bowl","url":"/super-bowl"},{"metrics":{"eventName":"clickAction","linkModule":"navigation","linkName":"Combine","linkType":"global nav","linkUrl":"https://www.nfl.com/combine"},"target":null,"text":"Combine","url":"/combine"},{"metrics":{"eventName":"clickAction","linkModule":"navigation","linkName":"Draft","linkType":"global nav","linkUrl":"https://www.nfl.com/draft/home"},"target":null,"text":"Draft","url":"/draft/home"},{"metrics":{"eventName":"clickAction","linkModule":"navigation","linkName":"Highlights","linkType":"global nav","linkUrl":"https://www.nfl.com/videos/highlights"},"target":null,"text":"Highlights","url":"/videos/highlights"},{"metrics":{"eventName":"clickAction","linkModule":"navigation","linkName":"Stats","linkType":"global nav","linkUrl":"https://www.nfl.com/stats/player"},"target":null,"text":"Stats","url":"/stats/player"},{"metrics":{"eventName":"clickAction","linkModule":"navigation","linkName":"Next Gen Stats","linkType":"global nav","linkUrl":"https://www.nfl.com/stats/next-gen-stats"},"target":"_blank","text":"Next Gen Stats","url":"/stats/next-gen-stats"},{"metrics":{"eventName":"clickAction","linkModule":"navigation","linkName":"Ways to Watch","linkType":"global nav","linkUrl":"https://www.nfl.com/ways-to-watch"},"target":null,"text":"Ways t ...
#              __REACT_ROOT_ID__ = "content";
#          </script>,
#  <script>
#              if (Math.floor((Math.random() * 100) + 1) <= 10) { // then include AppD
#                  window["adrum-config"] = window["adrum-config"] || {};
#
#                  (function (config) {
#                      config.xd = config.xd || {};
#                      config.userEventInfo = config.userEventInfo || {};
#
#                      (function (xd, userEventInfo) {
#                          xd.enable = true;
#                          userEventInfo.PageView = function pageViewCallback() {
#                              return {
#                                  userDataDouble: {
#                                      first_byte: 0,
#                                      first_render: 0,
#                                      interactive: 0
#                                  }
#                              };
#                          }
#                          userEventInfo.VPageView = function vPageViewCallback() {
#                              return {
#                                  userDataDouble: {
#                                      first_byte: 0,
#                                      first_render: 0,
#                                      interactive: 0
#                                  }
#                              };
#                          }
#                      }(config.xd, config.userEventInfo));
#                  }(window["adrum-config"]));
#
#                  document.write("\x3Cscript src=\"//p.nfltags.com/appd/adrum-4.3.0.0.js\">\x3C/script>");
#              }
#          </script>,
#  <script crossorigin="" defer="" src="https://static-wildcat.nfl.com/bundles/manifest.614925ae.bundle.js"></script>,
#  <script crossorigin="" defer="" src="https://static-wildcat.nfl.com/bundles/www.nfl.a3353443.bundle.js"></script>,
#  <script>
#      (function(s, p, d) {
#        var h=d.location.protocol, i=p+"-"+s,
#            e=d.getElementById(i), r=d.getElementById(p+"-root"),
#            u=h==="https:"?"d1z2jf7jlzjs58.cloudfront.net"
#            :"static."+p+".com";
#        if (e) return;
#        e = d.createElement(s); e.id = i; e.async = true;
#        e.src = h+"//"+u+"/p.js"; r.appendChild(e);
#      })("script", "parsely", document);
#  </script>]

# %%
html.findAll('script',attrs={"playDescription"})
# Out:
# []

# %%
a= html.find_all('div', attrs={'class': "css-7w6khc"})

# %%
a
# Out:
# []

# %%
import pandas as pd

# %%
X=pd.DataFrame({'ofertas':[200000,50000],'monto_prom_enviada':[300000,200000],'ofertas_aceptadas':[20100,10000],
               'monto_promedio_tomado':[275000,200000]})
Y=pd.DataFrame({'ofertas':[10000,1000],'monto_prom_enviada':[300000,200000],'ofertas_aceptadas':[420,50],
               'monto_promedio_tomado':[175000,200000]})
X['poblacion']=['A','B']
Y['poblacion']=['A','B']
X.set_index('poblacion',inplace=True)
Y.set_index('poblacion',inplace=True)

# %%
X['estandarizado']=X.ofertas_aceptadas/X.ofertas
Y['estandarizado']=Y.ofertas_aceptadas/Y.ofertas

# %%
X['porcentaje_monto_aceptado']=X.monto_promedio_tomado/X.monto_prom_enviada
Y['porcentaje_monto_aceptado']=Y.monto_promedio_tomado/Y.monto_prom_enviada

# %%
X
# Out:
#            ofertas  monto_prom_enviada  ofertas_aceptadas  \
# poblacion
# A           200000              300000              20100
# B            50000              200000              10000
#
#            monto_promedio_tomado  estandarizado  porcentaje_monto_aceptado
# poblacion
# A                         275000         0.1005                   0.916667
# B                         200000         0.2000                   1.000000

# %%
Y
# Out:
#            ofertas  monto_prom_enviada  ofertas_aceptadas  \
# poblacion
# A            10000              300000                420
# B             1000              200000                 50
#
#            monto_promedio_tomado  estandarizado  porcentaje_monto_aceptado
# poblacion
# A                         175000          0.042                   0.583333
# B                         200000          0.050                   1.000000
